# %%
# Opening a File
file=open('D:\\Documents\\Computer Course\\phyton\\New folder\\File Handling\\file.txt','r')
content = file.read() # to read the file
print(content)
file.close()
# Out:
# HEllo World

# %%
# this is a write mode data
file=open('D:\\Documents\\Computer Course\\phyton\\New folder\\File Handling\\file2.txt','w')
content =(input("Enter the data to write"))
file.write(content)
print("Data saved successfully")
file.close()
# Out:
# Data saved successfully

# %%
# reading the 2 file which we created above
file=open('D:\\Documents\\Computer Course\\phyton\\New folder\\File Handling\\file2.txt','r')
content=file.read()
print(content)
file.close()
# Out:
# My Name is manoj singh

# %%
# with statement
with open('D:\\Documents\\Computer Course\\phyton\\New folder\\File Handling\\data.txt','w') as file:
 content=input("Enter the content to write")
 file.write(content)
 print('saved')
# Out:
# saved

# %%
# append mode
with open('D:\\Documents\\Computer Course\\phyton\\New folder\\File Handling\\data.txt','a') as file:
    content=(input("Enter data to append"))
    file.write(content)
    print('appended successfully')
# Out:
# appended successfully

# %%
# to check file is exist or not
import os

if os.path.exists('D:\\Documents\\Computer Course\\phyton\\New folder\\File Handling\\data10.txt'):
    print("file exists")
else:
    print("file does not exist")
# Out:
# file does not exist
